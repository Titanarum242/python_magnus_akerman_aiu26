# %% [markdown]
# # Exercise 1 - Count with python
#
# In this exercise, you get to familiarize yourself with fundamental Python. This exercise covers lectures 04 in the course.
#
# ## 0. Pythagorean theorem (*)
#
# a) A right angled triangle has the catheti: a = 3 and b = 4 length units. Compute the hypothenuse of the triangle. (\*)
#
# b) A right angled triangle has hypothenuse c = 7.0 and a cathetus a = 5.0 length units. Compute the other cathetus and round to one decimal. (\*)

# %%
#A) #SVAR:
a =float(3)
b =float(4)


c =((a**2)+(b**2))**0.5
type(a),type(b),type(c)
c
# Out:
# 5.0

# %%
#B SVAR:
hypethenuse = c =float(7.0)
cathetus1 = a =float(5.0)
cathetus2 = b =float(b)
type(a),type(c),type(cathetus2)
b=((c**2)-(a**2))**0.5
round(b,1)
# Out:
# 4.9

# %% [markdown]
# ## 1. Classification accuracy (\*)
#
# A machine learning algorithm has been trained to predict whether or not it would rain the next day. Out of 365 predictions, it got 300 correct, compute the accuracy of this model.

# %%
#SVAR
predictions_total = float(365)
correct_ans = float(300)

model=model_accuracy= print(round((correct_ans/predictions_total)*100,1),"%")
# Out:
# 82.2 %

# %% [markdown]
# ## 2. Classification accuracy (\*)
#
# A machine learning model has been trained to detect fire. Here is the result of its predictions:
#
# <table>
# <tbody>
#   <tr>
#     <td>True Positive (TP)
#       <ul>
#         <li>Reality: fire</li>
#         <li>Predicted: fire</li>
#         <li>Number of TP: 2</li>
#       </ul>
#     </td>
#     <td>False Positive (FP)
#       <ul>
#         <li>Reality: no fire</li>
#         <li>Predicted: fire</li>
#         <li>Number of FP: 2</li>
#       </ul>
#     </td>
#   </tr>
#
#   <tr>
#     <td>False Negative (FN)
#       <ul>
#         <li>Reality: fire</li>
#         <li>Predicted: no fire</li>
#         <li>Number of FN: 11</li>
#       </ul>
#     </td>
#     <td>True Negative (TN)
#       <ul>
#         <li>Reality: no fire</li>
#         <li>Predicted: no fire</li>
#         <li>Number of TN: 985</li>
#       </ul>
#     </td>
#   </tr>
# </tbody>
# </table>
#
# Calculated the accuracy using the following formula:
#
# $\text{accuracy} = \frac{TP+TN}{TP+TN+FP+FN}$
#
# Is this a good model? Why? Why not?

# %%
#no real FIRE
FP=float(2)
TN=float(985)
#FIRE 
FN=float(11)
TP=float(2)
accuracy=print((TP+TN)/(TP+TN+FP+FN)*100,"%")
#The importance should be to detect real fires so NO it is not a accurate model.
accuracy_real_fires=(TP/FN)*100
print(round(accuracy_real_fires,1),"%")
# Out:
# 98.7 %
# 18.2 %

# %% [markdown]
# ## 3. File metadata - format print (*)
#
# There is a file with the following metadata:
#
# - name: orders_data.csv
# - file size: 3.14mb
# - modified 2024
#
# Create variables for each of them and print out the following to the screen
#
# ```
# === File metadata ===
# Filename: sales_data.csv
# Size (MB): 24.7
# Last Modified Year: 2023
# ```

# %%
name="orders_data.csv"
Size = float(3.14)
year = int(2024)
print("=== File metadata ==="), 
print("Filename:",name),
print("Size (MB):",Size,"mb"),
print("Last Modified Year:",year)
# Out:
# === File metadata ===
# Filename: orders_data.csv
# Size (MB): 3.14 mb
# Last Modified Year: 2024

# %% [markdown]
# # IF Statements

# %%
age = 13
age_limit = 18
if age>=age_limit:
    print("Welcome to the pub")
else:
    print("you are to young")
# Out:
# you are to young

# %%
# Balder
# requirements: 140cm max 190cm
# At least 12 years old
age =13
length =141

    print("not ok")
# Out:
#   Cell In[169], line 7
#     print("not ok")
#     ^
# IndentationError: unexpected indent

# %%
# B: 80
# C: 70
# D: 60
# E: 50
# F: 40
